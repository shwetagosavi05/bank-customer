# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("Bank Customer Churn Prediction.csv")

# %%
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
df.describe()
# Out:
#         customer_id  credit_score           age        tenure        balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        products_number  credit_card  active_member  estimated_salary  \
# count     10000.000000  10000.00000   10000.000000      10000.000000
# mean          1.530200      0.70550       0.515100     100090.239881
# ...

# %%
#average credit score is 652.0
#average age is 37 year
#average tenure is  5 year
# average  balance is  97198 rs.

# %%
df.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
# No null values

# %%
p=df.hist(figsize=(20,18))

# %%
sns.countplot(x = 'gender', data = df)
# Out:
# <AxesSubplot: xlabel='gender', ylabel='count'>

# %%
#Female are 4500
#Male are  more than 5000

# %%
plt.figsize=(20,10)
sns.countplot(x ='age', data = df)
# Out:
# <AxesSubplot: xlabel='age', ylabel='count'>

# %%
sns.countplot(x ='active_member', data = df)
# Out:
# <AxesSubplot: xlabel='active_member', ylabel='count'>

# %%
#more than 5000 are active and around close to 5000 are non active member

# %%
sns.countplot(x ='country', data = df)
# Out:
# <AxesSubplot: xlabel='country', ylabel='count'>

# %%
df.groupby(['country']).sum().plot(kind='pie', y='active_member', autopct='%1.0f%%')
# Out:
# <AxesSubplot: ylabel='active_member'>

# %%
#France active member are 50%
#germany has 24% active member
#spain has  25% active member

# %%
df.groupby(['country']).sum().plot(kind='pie', y='balance', autopct='%1.0f%%')
# Out:
# <AxesSubplot: ylabel='balance'>

# %%
#france has 41% balance
#germany has 39%balance
#spain has 20%balance

# %%
df.groupby(['country']).sum().plot(kind='pie', y='churn', autopct='%1.0f%%')
# Out:
# <AxesSubplot: ylabel='churn'>

# %%
#france has 40%  churn
#germany has 40% churn
#spain has 20% churn

# %%
df.groupby(['country']).sum().plot(kind='pie', y='age', autopct='%1.0f%%')
# Out:
# <AxesSubplot: ylabel='age'>

# %%
sns.distplot(df['age'])
# Out:
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
sns.histplot(df["balance"])
# Out:
# <AxesSubplot: xlabel='balance', ylabel='Count'>

# %%
cat_cols=df.select_dtypes(include=("O")).columns
cat_cols
# Out:
# Index(['country', 'gender'], dtype='object')

# %%
no_cols=df.select_dtypes(include=("int","float")).columns
no_cols
# Out:
# Index(['customer_id', 'credit_score', 'age', 'tenure', 'balance',
#        'products_number', 'credit_card', 'active_member', 'estimated_salary',
#        'churn'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for i in cat_cols:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619        0       0   42       2       0.00
# 1        15647311           608        2       0   41       1   83807.86
# 2        15619304           502        0       0   42       8  159660.80
# 3        15701354           699        0       0   39       1       0.00
# 4        15737888           850        2       0   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771        0       1   39       5       0.00
# 9996     15569892           516        0       1   35      10   57369.61
# 9997     15584532           709        0       0   36       7       0.00
# 9998     15682355           772        1       1   42       3   75075.31
# 9999     15628319           792        0       0   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
#balance and country are corelated

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=123)

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
X_test.shape
# Out:
# (2000, 11)

# %%
y_train.shape
# Out:
# (8000,)

# %%
y_test.shape
# Out:
# (2000,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier  
from sklearn.svm import SVC

# %%
le=LinearRegression()
lr=LogisticRegression()
kn=KNeighborsClassifier()
dt=DecisionTreeClassifier()
rc=RandomForestClassifier()
svm=SVC(kernel='linear')

# %%
from sklearn.metrics import classification_report
def my_model(model):
    model.fit(X_train,y_train)
    y_pred_train=model.predict(X_train)
    y_pred_test=model.predict(X_test)
    print("train data")
    print(classification_report(y_train,y_pred_train))
    print("test data")
    print(classification_report(y_test,y_pred_test))
    return model

# %%
my_model(kn)
# Out:
# train data
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      6377
#            1       0.62      0.20      0.31      1623
#
#     accuracy                           0.81      8000
#    macro avg       0.72      0.59      0.60      8000
# weighted avg       0.78      0.81      0.77      8000
#
# test data
#               precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86      1586
#            1       0.23      0.07      0.11       414
#
#     accuracy                           0.76      2000
#    macro avg       0.51      0.51      0.49      2000
# weighted avg       0.68      0.76      0.71      2000
# KNeighborsClassifier()

# %%
my_model(dt)
# Out:
# train data
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6377
#            1       1.00      1.00      1.00      1623
#
#     accuracy                           1.00      8000
#    macro avg       1.00      1.00      1.00      8000
# weighted avg       1.00      1.00      1.00      8000
#
# test data
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87      1586
#            1       0.49      0.51      0.50       414
#
#     accuracy                           0.79      2000
#    macro avg       0.68      0.69      0.68      2000
# weighted avg       0.79      0.79      0.79      2000
# DecisionTreeClassifier()

# %%
from sklearn import tree

# %%
fig,ax=plt.subplots(figsize=(40,25))
chart=tree.plot_tree(dt,max_depth=3,feature_names=X.columns,filled=True,fontsize=10)

# %%
from sklearn.metrics import accuracy_score
for i in range(1,15):
    dt=DecisionTreeClassifier(max_depth=i)
    dt.fit(X_train,y_train)
    y_pred_train=dt.predict(X_train)
    y_pred_test=dt.predict(X_test)
    print("Train data-max depth=",i)
    print(accuracy_score(y_train,y_pred_train))
    print("Test data")
    print(accuracy_score(y_test,y_pred_test))
# Out:
# Train data-max depth= 1
# 0.797125
# Test data
# 0.793
# Train data-max depth= 2
# 0.82975
# Test data
# 0.828
# Train data-max depth= 3
# 0.8425
# Test data
# 0.837
# Train data-max depth= 4
# 0.849375
# Test data
# 0.842
# Train data-max depth= 5
# 0.857125
# Test data
# 0.854
# Train data-max depth= 6
# 0.8615
# Test data
# 0.8515
# Train data-max depth= 7
# 0.869
# Test data
# 0.8495
# Train data-max depth= 8
# 0.877875
# Test data
# 0.856
# Train data-max depth= 9
# 0.888375
# Test data
# 0.8555
# Train data-max depth= 10
# 0.902125
# Test data
# 0.842
# Train data-max depth= 11
# 0.917
# Test data
# 0.835
# Train data-max depth= 12
# 0.9355
# Test data
# 0.825
# Train data-max depth= 13
# 0.949625
# Test data
# 0.8195
# Train data-max depth= 14
# 0.961875
# Test data
# 0.817

# %%
my_model(lr)
# Out:
# train data
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      6377
#            1       0.00      0.00      0.00      1623
#
#     accuracy                           0.80      8000
#    macro avg       0.40      0.50      0.44      8000
# weighted avg       0.64      0.80      0.71      8000
#
# test data
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88      1586
#            1       0.00      0.00      0.00       414
#
#     accuracy                           0.79      2000
#    macro avg       0.40      0.50      0.44      2000
# weighted avg       0.63      0.79      0.70      2000
# LogisticRegression()

# %%
my_model(rc)
# Out:
# train data
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6377
#            1       1.00      1.00      1.00      1623
#
#     accuracy                           1.00      8000
#    macro avg       1.00      1.00      1.00      8000
# weighted avg       1.00      1.00      1.00      8000
#
# test data
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      1586
#            1       0.76      0.45      0.56       414
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.70      0.74      2000
# weighted avg       0.85      0.86      0.84      2000
# RandomForestClassifier()

# %%
my_model(svm)
# Out:
# train data
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      6377
#            1       0.00      0.00      0.00      1623
#
#     accuracy                           0.80      8000
#    macro avg       0.40      0.50      0.44      8000
# weighted avg       0.64      0.80      0.71      8000
#
# test data
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88      1586
#            1       0.00      0.00      0.00       414
#
#     accuracy                           0.79      2000
#    macro avg       0.40      0.50      0.44      2000
# weighted avg       0.63      0.79      0.70      2000
# SVC(kernel='linear')

# %%
y_train_proba=lr.predict_proba(X_train)[:,1]
y_train_proba
# Out:
# array([0.14169061, 0.14381249, 0.14449861, ..., 0.21582924, 0.21537886,
#        0.1411697 ])

# %%
y_test_proba=lr.predict_proba(X_test)[:,1]
y_test_proba
# Out:
# array([0.14421292, 0.2021568 , 0.20126032, ..., 0.21197479, 0.22957989,
#        0.22818046])

# %%
from sklearn.metrics import precision_recall_curve,f1_score,roc_auc_score
p,r,th=precision_recall_curve(y_train,y_train_proba)

# %%
plt.figure(figsize=(6,6))
sns.lineplot(x=th,y=p[:-1],label="precision")
sns.lineplot(x=th,y=r[:-1],label="Recall")
plt.axvline(0.248)

# %%
#Precision-Recall curves summarize the trade-off between the true positive rate and the positive predictive value

# %%
from sklearn.metrics import roc_curve,auc
fpr,tpr,th=roc_curve(y_train,y_train_proba)
sns.lineplot(x=fpr,y=tpr)
sns.lineplot(x=[0.0,1.0],y=[0.0,1.0],color="red",linestyle="--")
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC-AUC Curve")
# Out:
# Text(0.5, 1.0, 'ROC-AUC Curve')

# %%
#ROC Curves summarize the trade-off between the true positive rate and false positive rate

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada=AdaBoostClassifier()

# %%
my_model(ada)
# Out:
# train data
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      6377
#            1       0.72      0.47      0.57      1623
#
#     accuracy                           0.86      8000
#    macro avg       0.80      0.71      0.74      8000
# weighted avg       0.84      0.86      0.84      8000
#
# test data
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1586
#            1       0.74      0.49      0.59       414
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
# AdaBoostClassifier()

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb=GradientBoostingClassifier()

# %%
my_model(gb)
# Out:
# train data
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      6377
#            1       0.83      0.48      0.60      1623
#
#     accuracy                           0.87      8000
#    macro avg       0.85      0.72      0.76      8000
# weighted avg       0.87      0.87      0.86      8000
#
# test data
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1586
#            1       0.78      0.45      0.57       414
#
#     accuracy                           0.86      2000
#    macro avg       0.82      0.71      0.74      2000
# weighted avg       0.85      0.86      0.84      2000
# GradientBoostingClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_grid={'criterion':['entropy',"gini"],
           'max_depth':np.arange(3,51),
           'min_samples_split':np.arange(1,51),
           'min_samples_leaf':np.arange(1,51),
           'max_features':['log','auto',None]}

# %%
rg=RandomizedSearchCV(estimator=ada, param_distributions=param_grid,cv = 2, n_iter = 10, n_jobs=-1)

# %%
y_pred_train=lr.predict(X_train)
y_pred_test=lr.predict(X_test)

# %%
print('Train data')
print(classification_report(y_train,y_pred_train))
print('Test data')
print(classification_report(y_test,y_pred_test))
# Out:
# Train data
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      6377
#            1       0.00      0.00      0.00      1623
#
#     accuracy                           0.80      8000
#    macro avg       0.40      0.50      0.44      8000
# weighted avg       0.64      0.80      0.71      8000
#
# Test data
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88      1586
#            1       0.00      0.00      0.00       414
#
#     accuracy                           0.79      2000
#    macro avg       0.40      0.50      0.44      2000
# weighted avg       0.63      0.79      0.70      2000

# %%
rg=RandomizedSearchCV(estimator=gb, param_distributions=param_grid,cv = 2, n_iter = 10, n_jobs=-1)

# %%
y_pred_train=ada.predict(X_train)
y_pred_test=ada.predict(X_test)

# %%
print('Train data')
print(classification_report(y_train,y_pred_train))
print('Test data')
print(classification_report(y_test,y_pred_test))
# Out:
# Train data
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      6377
#            1       0.72      0.47      0.57      1623
#
#     accuracy                           0.86      8000
#    macro avg       0.80      0.71      0.74      8000
# weighted avg       0.84      0.86      0.84      8000
#
# Test data
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1586
#            1       0.74      0.49      0.59       414
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
    "n_estimators":[100,200,300,400],
    "learning_rate":[0.1,0.01,0.001,1],
    "algorithm":['SAMME', 'SAMME.R'],
   
    
}

# %%
model=GridSearchCV(ada,param_grid=param_grid,cv=5,scoring="accuracy",n_jobs=-1)

# %%
model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.1, 0.01, 0.001, 1],
#                          'n_estimators': [100, 200, 300, 400]},
#              scoring='accuracy')

# %%
print('Train data')
print(classification_report(y_train,y_pred_train))
print('Test data')
print(classification_report(y_test,y_pred_test))
# Out:
# Train data
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      6377
#            1       0.72      0.47      0.57      1623
#
#     accuracy                           0.86      8000
#    macro avg       0.80      0.71      0.74      8000
# weighted avg       0.84      0.86      0.84      8000
#
# Test data
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1586
#            1       0.74      0.49      0.59       414
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000

# %%
data={
    "models":["KNeighborsClassifier","DecisionTreeClassifier","LogisticRegression","RandomForestClassifier","SVC","AdaBoostClassifier","GradientBoostingClassifier","Randomised search cv with ada","Randomised search cv with gb","grid search cv ada"],
    "Train accuracy":[81,1,80,1,80,86,87,80,86,86],
    "Test accuracy":[76,79,79,86,79,86,86,79,86,86]
}
df1=pd.DataFrame(data)

# %%
df1
# Out:
#                           models  Train accuracy  Test accuracy
# 0           KNeighborsClassifier              81             76
# 1         DecisionTreeClassifier               1             79
# 2             LogisticRegression              80             79
# 3         RandomForestClassifier               1             86
# 4                            SVC              80             79
# 5             AdaBoostClassifier              86             86
# 6     GradientBoostingClassifier              87             86
# 7  Randomised search cv with ada              80             79
# 8   Randomised search cv with gb              86             86
# 9              grid sarch cv ada              86             86

# %%
#out od all the models used ADA boost works best on the data set with having accuracy for train dataset 86 and test accuracy of 86
